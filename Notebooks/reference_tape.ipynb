# %% [markdown]
# # Final Software

# %%
import cv2
import os
import sys
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

path_to_script="/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2"
sys.path.append(path_to_script)
# Out:
# In /home/gari/anaconda3/envs/deep_amt/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In /home/gari/anaconda3/envs/deep_amt/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/gari/anaconda3/envs/deep_amt/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In /home/gari/anaconda3/envs/deep_amt/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/gari/anaconda3/envs/deep_amt/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# ...

# %%
from Auxiliar.ReferenceDetector import ReferenceDetector

# %%
path="/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/Notebooks/photos_in/s2/"
image_1=path+"super.JPG"
imgcv = cv2.imread(image_1)
plt.imshow(imgcv)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
path_template="/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/Auxiliar/tape_template_2.jpg"
template=cv2.imread(path_template)
length=2

# %%
rd=ReferenceDetector(template=template,length=length)

# %%
ratio=rd.get_ratio(image=imgcv,show_on_picture=True)
# Out:
# maximum pixel distance 295

# %%
ratio*500
# Out:
# 3.389830508474576

# %%
#import fish_detector as fd

# %%
#%run /media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/fish_detector.py False False False

# %%
#%run /media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/fish_detector.py False True False

# %% [markdown]
# # Senegal Sample

# %%
# %run /media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/fish_detector_temp_2.py False True False
# Out:
# ****************************************************************************************************
# {'imgdir': './sample_img/', 'binary': './bin/', 'config': './cfg/', 'dataset': '../pascal/VOCdevkit/IMG/', 'labels': 'labels.txt', 'backup': './ckpt/', 'summary': '', 'annotation': '../pascal/VOCdevkit/ANN/', 'threshold': 0.05, 'model': '', 'trainer': 'rmsprop', 'momentum': 0.0, 'verbalise': True, 'train': False, 'load': '', 'savepb': False, 'gpu': 0.0, 'gpuName': '/gpu:0', 'lr': 1e-05, 'keep': 20, 'batch': 16, 'epoch': 1000, 'save': 2000, 'demo': '', 'queue': 1, 'json': False, 'saveVideo': False, 'pbLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.pb', 'metaLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.meta'}
#
# Loading from .pb and .meta
# Running entirely on CPU
# ((303, 173), (391, 233), True)
# ((303, 173), (391, 233), True)
# ((382, 118), (441, 170), True)
# ...

# %% [markdown]
# # Palau Sample

# %%
# %run /media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/fish_detector_temp_2.py False True False
# Out:
# ****************************************************************************************************
# {'imgdir': './sample_img/', 'binary': './bin/', 'config': './cfg/', 'dataset': '../pascal/VOCdevkit/IMG/', 'labels': 'labels.txt', 'backup': './ckpt/', 'summary': '', 'annotation': '../pascal/VOCdevkit/ANN/', 'threshold': 0.05, 'model': '', 'trainer': 'rmsprop', 'momentum': 0.0, 'verbalise': True, 'train': False, 'load': '', 'savepb': False, 'gpu': 0.0, 'gpuName': '/gpu:0', 'lr': 1e-05, 'keep': 20, 'batch': 16, 'epoch': 1000, 'save': 2000, 'demo': '', 'queue': 1, 'json': False, 'saveVideo': False, 'pbLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.pb', 'metaLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.meta'}
#
# Loading from .pb and .meta
# Running entirely on CPU
# ((370, 134), (462, 210), True)
# ((370, 134), (462, 210), True)
# ((415, 151), (480, 230), True)
# ...

# %% [markdown]
# # Original DB

# %%
# %run /media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/fish_detector_temp_2.py False True False
# Out:
# ****************************************************************************************************
# {'imgdir': './sample_img/', 'binary': './bin/', 'config': './cfg/', 'dataset': '../pascal/VOCdevkit/IMG/', 'labels': 'labels.txt', 'backup': './ckpt/', 'summary': '', 'annotation': '../pascal/VOCdevkit/ANN/', 'threshold': 0.05, 'model': '', 'trainer': 'rmsprop', 'momentum': 0.0, 'verbalise': True, 'train': False, 'load': '', 'savepb': False, 'gpu': 0.0, 'gpuName': '/gpu:0', 'lr': 1e-05, 'keep': 20, 'batch': 16, 'epoch': 1000, 'save': 2000, 'demo': '', 'queue': 1, 'json': False, 'saveVideo': False, 'pbLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.pb', 'metaLoad': '/media/gari/extra_ssd/folders/Jacobs_resourses/AMT_V2/built_graph/yolov2-custum-fish.meta'}
#
# Loading from .pb and .meta
# Running entirely on CPU
# ((503, 80), (642, 239), True)
# ((503, 80), (642, 239), True)
# ((401, 62), (525, 269), True)
# ((401, 62), (525, 269), True)
# ...

# %%
import numpy as np

# %%
colors=[tuple(255 * np.random.rand(3)) for i in range(5)]

# %%
colors
# Out:
# [(165.38465819218737, 53.85496707367241, 83.42019178011603),
#  (80.40783118654004, 90.35930014697577, 83.14559151428358),
#  (169.48236563665242, 46.57534551111705, 138.74385121902392),
#  (152.7156841432019, 117.78225590918754, 244.85089115576196),
#  (144.81928721821703, 46.00587218882722, 148.7589762771596)]
